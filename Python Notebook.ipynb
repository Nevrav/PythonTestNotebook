# %%
print ('Hello, Python!')
# Out:
# Hello, Python!

# %%
# Check the Python Version

import sys
print(sys.version)
# Out:
# 3.5.5 |Anaconda, Inc.| (default, May 13 2018, 21:12:35)
# [GCC 7.2.0]

# %%
# Practice on writing comments

print('Hello, Python!') # This line prints a string
# print('Hi')
# Out:
# Hello, Python!

# %%
# Print string as error message

frint("Hello, Python!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bc81942a2137> in <module>()
#       1 # Print string as error message
#       2
# ----> 3 frint("Hello, Python!")
#
# NameError: name 'frint' is not defined

# %%
# Try to see build in error message

print("Hello, Python!)
# Out:
#   File "<ipython-input-7-5bdb04fa43c5>", line 3
#     print("Hello, Python!)
#                           ^
# SyntaxError: EOL while scanning string literal

# %%
# Print string and error to see the running order

print("This will be printed")
frint("This will cause an error")
print("This will NOT be printed")
# Out:
# This will be printed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8fb0611ec76e> in <module>()
#       2
#       3 print("This will be printed")
# ----> 4 frint("This will cause an error")
#       5 print("This will NOT be printed")
#
# NameError: name 'frint' is not defined

# %%
type (12.3)
# Out:
# float

# %%
type (47)
# Out:
# int

# %%
type ("Hello, python!")
# Out:
# str

# %%
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
type(2)
# Out:
# int

# %%
float(2)
# Out:
# 2.0

# %%
type(float(2))
# Out:
# float

# %%
float(2)
# Out:
# 2.0

# %%
type(int(2.0))
# Out:
# int

# %%
int(2.0)
# Out:
# 2

# %%
str(2)
# Out:
# '2'

# %%
int('1 or 2 people')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-82b2b85b3a38> in <module>()
# ----> 1 int('1 or 2 people')
#
# ValueError: invalid literal for int() with base 10: '1 or 2 people'

# %%
str(1.2)
# Out:
# '1.2'

# %%
#Value False

# %%
bool(True)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool(2.3)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool (-1)
# Out:
# True

# %%
type(False)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
6/2
# Out:
# 3.0

# %%
6//2
# Out:
# 3

# %%
x = 7

# %%
x * 2
# Out:
# 14

# %%
14 // x
# Out:
# 2

# %%
x / 3
# Out:
# 2.3333333333333335

# %%
x // 3
# Out:
# 2
